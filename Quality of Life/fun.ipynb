# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw

# %%
mol = Chem.MolFromSmiles('Cc1c(c(nn1C1CC2(C1)CN(C2)C(=O)C=C)-c1cccnc1)-c1c(Cl)ccc2[nH]ncc12')

# %%
Draw.MolToImage(mol)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
